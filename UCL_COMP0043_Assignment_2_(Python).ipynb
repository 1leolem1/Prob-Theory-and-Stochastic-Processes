# %% [markdown]
# <a href="https://colab.research.google.com/github/leopauls/COMP0045---Prob-Theory-/blob/main/UCL_COMP0043_Assignment_2_(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![COMP0043_assignment2.jpg](data:image/jpeg;base64,...)
